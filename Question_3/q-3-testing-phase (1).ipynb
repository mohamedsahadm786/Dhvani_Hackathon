# %%
def pip_install(pkg):
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--no-input", pkg])
        print("Installed:", pkg)
        return True
    except Exception as e:
        print("Failed:", pkg, "→", e)
        return False




# Multi-label stratification (try options in order)
ok_iter = pip_install("iterative-stratification==0.1.7")
if not ok_iter:
    ok_iter = pip_install("scikit-multilearn==0.2.0")
# Out:
# Failed: iterative-stratification==0.1.7 → name 'subprocess' is not defined
# Failed: scikit-multilearn==0.2.0 → name 'subprocess' is not defined

# %%
pip install ultralytics==8.*
# Out:
# Collecting ultralytics==8.*
#   Downloading ultralytics-8.3.178-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.*) (2.2.3)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics==8.*)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.*) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics==8.*) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics==8.*) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics==8.*) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics==8.*) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics==8.*) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics==8.*) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.*) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.*) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.*) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.*) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.*) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.*) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics==8.*)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.*) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.*) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.*) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.*) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics==8.*) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics==8.*) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.0->ultralytics==8.*) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.0->ultralytics==8.*) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.0->ultralytics==8.*) (2024.2.0)
# Downloading ultralytics-8.3.178-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.2 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 27.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.4 MB/s eta 0:00:00:00:0100:01
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.178 ultralytics-thop-2.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
# ==================== 1) CONFIG ======================
import os, glob, shutil
from pathlib import Path
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# --- Paths from your "Input" panel ---
BEST_MODEL_DIR = "/kaggle/input/best-model"
TEST_DIR       = "/kaggle/input/vehicle-detection-dataset/test1/test"

# %%
# Expect these exact filenames (as per your screenshot)
WEIGHTS  = f"{BEST_MODEL_DIR}/phase2_epoch59.pt"
DATA_YAML = f"{BEST_MODEL_DIR}/data.yaml"  # only for sanity/class order; not required for predict()

# %%
# Output
OUT_DIR  = "/kaggle/working/vehdet/preds_test"
RUN_NAME = "epoch59_infer"

# %%
# Inference knobs (precision-leaning defaults)
IMG_SIZE_PREF = 1024     # falls back to 896 if OOM
CONF_BASE     = 0.30     # raise to cut false positives (try 0.30–0.35)
NMS_IOU       = 0.55     # more aggressive NMS to remove near-duplicates
USE_TTA       = True     # mild bump; disable if in a rush

# %%
# Optional: class-specific minimum conf (post-filter in CSV)
# Example: tighten motorbike only:
PER_CLASS_MIN_CONF = {
    # "motorbike": 0.33,
}

# %%
# ==================== 2) CHECKS ======================
assert os.path.isdir(TEST_DIR), f"Test folder not found: {TEST_DIR}"
assert os.path.exists(WEIGHTS), f"Weights not found: {WEIGHTS}"
os.makedirs(OUT_DIR, exist_ok=True)

print("Using weights:", WEIGHTS)
if os.path.exists(DATA_YAML):
    print("Found data.yaml:", DATA_YAML)
# Out:
# Using weights: /kaggle/input/best-model/phase2_epoch59.pt
# Found data.yaml: /kaggle/input/best-model/data.yaml

# %%
# ==================== 3) LOAD MODEL ==================
model = YOLO(WEIGHTS)
print("Model classes (order matters):", model.names)
# Out:
# Model classes (order matters): {0: 'car', 1: 'rickshaw', 2: 'bus', 3: 'motorbike'}

# %%
# ==================== 4) INFERENCE ===================
def run_predict(imgsz):
    return model.predict(
        source=TEST_DIR,
        imgsz=imgsz,
        conf=CONF_BASE,
        iou=NMS_IOU,
        device=0,
        half=True,
        augment=USE_TTA,
        save=True,        # annotated images
        save_txt=True,    # YOLO txt with conf
        save_conf=True,
        project=OUT_DIR,
        name=RUN_NAME,
        exist_ok=True
    )

try:
    print(f"Running inference @ imgsz={IMG_SIZE_PREF} ...")
    results = run_predict(IMG_SIZE_PREF)
    IMG_USED = IMG_SIZE_PREF
except Exception as e:
    print("Hit error at 1024, trying 896. Error:", e)
    results = run_predict(896)
    IMG_USED = 896

pred_dir = os.path.join(OUT_DIR, RUN_NAME)
print("✅ Predictions saved to:", pred_dir)
# Out:
# Running inference @ imgsz=1024 ...
#
# image 1/500 /kaggle/input/vehicle-detection-dataset/test1/test/Asraf_50_jpg.rf.7026694f0b9f37a6790982295c7e8663.jpg: 1024x1024 1 car, 1 motorbike, 165.8ms
# image 2/500 /kaggle/input/vehicle-detection-dataset/test1/test/Asraf_51_jpg.rf.0e3516baf7509bc2c4a4aa8deea494c2.jpg: 1024x1024 5 cars, 2 buss, 3 motorbikes, 90.4ms
# image 3/500 /kaggle/input/vehicle-detection-dataset/test1/test/Asraf_52_jpg.rf.867869f276e6db3a09a84b99643df316.jpg: 1024x1024 1 car, 1 bus, 1 motorbike, 89.7ms
# image 4/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(01)_jpg.rf.f935c7fc51a14c64e34c17a17c41cb1f.jpg: 1024x1024 2 cars, 2 buss, 83.9ms
# image 5/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(10)_jpg.rf.d163e2a53d5ed22112e9ead62807acf4.jpg: 1024x1024 4 cars, 4 rickshaws, 1 bus, 82.9ms
# image 6/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(11)_jpg.rf.36299290e6d6ce12423051e1f5084f05.jpg: 1024x1024 5 cars, 6 rickshaws, 82.7ms
# image 7/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(12)_jpg.rf.4da4073318b165b77ad9cc547cf82f1f.jpg: 1024x1024 1 car, 2 rickshaws, 4 buss, 82.7ms
# image 8/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(13)_jpg.rf.e6c5d0a3abb76ffe2051a6f336ac1a2a.jpg: 1024x1024 2 buss, 82.4ms
# image 9/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(14)_jpg.rf.801d6d37254ef2d3d43876bdcf5d9d54.jpg: 1024x1024 5 cars, 2 buss, 82.1ms
# image 10/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(15)_jpg.rf.d57eca49cdf9b53adfeaf1c6564b6179.jpg: 1024x1024 7 cars, 1 rickshaw, 82.1ms
# image 11/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(16)_jpg.rf.ac199a33569a2b6bf47a0c3267575364.jpg: 1024x1024 5 cars, 2 rickshaws, 82.3ms
# image 12/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(17)_jpg.rf.8ce702e750002516c990f17209c28900.jpg: 1024x1024 (no detections), 82.1ms
# image 13/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(18)_jpg.rf.2d99bbe6021834328af969e718d6b5df.jpg: 1024x1024 5 cars, 6 rickshaws, 82.7ms
# image 14/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(19)_jpg.rf.ded17b8863c2c0764d17b91e96012be0.jpg: 1024x1024 4 cars, 3 rickshaws, 82.2ms
# image 15/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(2)_jpg.rf.f68dcb552bc0b6c87c5e44f91499addc.jpg: 1024x1024 8 cars, 4 rickshaws, 1 bus, 82.5ms
# image 16/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(20)_jpg.rf.b3e6da0d8305a75df41638fcebe4c384.jpg: 1024x1024 2 cars, 12 rickshaws, 83.2ms
# image 17/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(21)_jpg.rf.9bcbc607d789a699bb41fa2ea9b80d85.jpg: 1024x1024 (no detections), 82.5ms
# image 18/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(22)_jpg.rf.93d244c57f2f22e50cb4840e3c985f84.jpg: 1024x1024 1 car, 2 rickshaws, 3 buss, 82.5ms
# image 19/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(23)_jpg.rf.420c4a7d3f78e2d7730fc60f0864642d.jpg: 1024x1024 (no detections), 83.1ms
# image 20/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(24)_jpg.rf.66060ac19e1ebaf7aaebf7b638a17178.jpg: 1024x1024 5 cars, 1 rickshaw, 1 bus, 82.7ms
# image 21/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(25)_jpg.rf.72a38d092bff9927369b31e8c5d5aaa3.jpg: 1024x1024 1 car, 82.5ms
# image 22/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(26)_jpg.rf.ef546854d56db3d8a951326eb388e814.jpg: 1024x1024 2 cars, 1 bus, 82.4ms
# image 23/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(27)_jpg.rf.8f4f0055ef757acbc315aa16e3da6b4b.jpg: 1024x1024 2 cars, 1 bus, 82.0ms
# image 24/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(28)_jpg.rf.35c946fd90c009f2c3577ff0445a2c28.jpg: 1024x1024 2 cars, 82.1ms
# image 25/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(29)_jpg.rf.5146bbea18e608fe5321c7c300e42184.jpg: 1024x1024 1 car, 1 bus, 83.3ms
# image 26/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(3)_jpg.rf.3e18a5ba51674a4be06858ab6252d43d.jpg: 1024x1024 3 rickshaws, 2 buss, 82.1ms
# image 27/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(30)_jpg.rf.0c063d2dfe93475ab12cc5dccd02e07c.jpg: 1024x1024 1 car, 1 bus, 82.3ms
# image 28/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(31)_jpg.rf.916fd18ead48a8371086f7f9d8db4406.jpg: 1024x1024 2 cars, 3 rickshaws, 1 bus, 82.5ms
# image 29/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(32)_jpg.rf.65d2860853702de08bb220d6bc0470df.jpg: 1024x1024 1 car, 2 buss, 81.8ms
# image 30/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(33)_jpg.rf.38f6d070be2bb427e0bf83209608a36e.jpg: 1024x1024 2 cars, 4 rickshaws, 1 bus, 82.0ms
# image 31/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(34)_jpg.rf.0fcb8495c4480f2b29e95b360286bf44.jpg: 1024x1024 2 cars, 9 rickshaws, 82.7ms
# image 32/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(35)_jpg.rf.98f18c7ded5c8a37767a21e9208c774e.jpg: 1024x1024 6 cars, 8 rickshaws, 1 bus, 82.0ms
# image 33/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(36)_jpg.rf.f432f0602c279655f3e0ed8b1157cef0.jpg: 1024x1024 5 cars, 6 rickshaws, 1 bus, 82.0ms
# image 34/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(37)_jpg.rf.3840b7892c829ec8010035e41bc777de.jpg: 1024x1024 5 cars, 7 rickshaws, 1 bus, 81.8ms
# image 35/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(38)_jpg.rf.0938b234884f5978919bd69e2aa4cb10.jpg: 1024x1024 8 cars, 1 rickshaw, 1 bus, 82.2ms
# image 36/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(39)_jpg.rf.a9b5d9bd87be13474283ab780c7272d6.jpg: 1024x1024 3 cars, 2 rickshaws, 1 bus, 1 motorbike, 82.3ms
# image 37/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(4)_jpg.rf.134cf55311b25147f3238699e22ac08d.jpg: 1024x1024 4 cars, 10 rickshaws, 1 bus, 82.1ms
# image 38/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(40)_jpg.rf.2041fba274021e625b2769437767cd62.jpg: 1024x1024 4 cars, 3 rickshaws, 1 bus, 1 motorbike, 81.9ms
# image 39/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(41)_jpg.rf.ab9f4f5b5c155f1079309acf156b73f3.jpg: 1024x1024 5 cars, 5 rickshaws, 2 buss, 82.0ms
# image 40/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(42)_jpg.rf.8c93439403401779f6ee5f2e0be77134.jpg: 1024x1024 3 cars, 8 rickshaws, 1 bus, 82.0ms
# image 41/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(43)_jpg.rf.7ba9cf4b4a0d334984f53d7b5e8b13ad.jpg: 1024x1024 4 cars, 7 rickshaws, 2 buss, 82.2ms
# image 42/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(44)_jpg.rf.a2609b6de321a3028e05bdbc63028b71.jpg: 1024x1024 4 cars, 3 rickshaws, 2 buss, 82.4ms
# image 43/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(45)_jpg.rf.79c61fd9b963bced2c2ca5f8197947ad.jpg: 1024x1024 6 cars, 2 rickshaws, 1 bus, 82.4ms
# image 44/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(46)_jpg.rf.e5737a496b19f46b6589a594c4f1caaf.jpg: 1024x1024 3 cars, 2 rickshaws, 82.3ms
# image 45/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(47)_jpg.rf.aab517edfa5c02dc21c0e529834f96a7.jpg: 1024x1024 3 cars, 3 rickshaws, 82.2ms
# image 46/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(48)_jpg.rf.3fe4068df9a50dd1976880abb51857a7.jpg: 1024x1024 1 car, 82.1ms
# image 47/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(49)_jpg.rf.593057a93ba74e1957eda6ba05f3324f.jpg: 1024x1024 5 rickshaws, 1 bus, 82.3ms
# image 48/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(5)_jpg.rf.e62581e20f276f714535e6f8cae111b5.jpg: 1024x1024 1 car, 3 rickshaws, 2 buss, 82.3ms
# image 49/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(50)_jpg.rf.554dda9957d00de20a89a6b67249c07e.jpg: 1024x1024 1 car, 4 rickshaws, 1 bus, 82.2ms
# image 50/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(51)_jpg.rf.079d042735b2e15f2e6a388ec482fe5a.jpg: 1024x1024 2 cars, 4 rickshaws, 2 buss, 82.2ms
# image 51/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(52)_jpg.rf.1671c6b5f623a354d6cf722e83d3acf0.jpg: 1024x1024 5 cars, 3 rickshaws, 1 bus, 82.2ms
# image 52/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(6)_jpg.rf.a4a4991e8321c66dc8e1d11f20c60a16.jpg: 1024x1024 1 car, 2 rickshaws, 82.2ms
# image 53/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(7)_jpg.rf.1c5a826117ba3cf7857a857c63df926a.jpg: 1024x1024 5 cars, 7 rickshaws, 2 buss, 83.2ms
# image 54/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(8)_jpg.rf.24900113770665f45ff44a6bc6c36911.jpg: 1024x1024 2 cars, 1 rickshaw, 3 buss, 82.0ms
# image 55/500 /kaggle/input/vehicle-detection-dataset/test1/test/Sabiha_(9)_jpg.rf.68b097af1cdddec0720654ab3fa721c0.jpg: 1024x1024 3 buss, 82.2ms
# image 56/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_001_jpg.rf.516873e00396352c2bb4475bcb6738c6.jpg: 1024x1024 (no detections), 82.0ms
# image 57/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_002_jpg.rf.e5811aad84e9b6f87fc0f1bd5b15757d.jpg: 1024x1024 1 bus, 81.9ms
# image 58/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_003_jpg.rf.fc87d1d909e73ea816f70e4b23bd7537.jpg: 1024x1024 1 bus, 81.8ms
# image 59/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_004_jpg.rf.83239eec04cacba9524f480e3a49f6d6.jpg: 1024x1024 5 cars, 1 bus, 82.3ms
# image 60/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_005_jpg.rf.2329d6008b655bb3179142e89a44f7b4.jpg: 1024x1024 1 car, 1 rickshaw, 82.1ms
# image 61/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_006_jpg.rf.cbaffebd7c9b1a7917969838fe4ec596.jpg: 1024x1024 1 car, 82.2ms
# image 62/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_007_jpg.rf.9133a6a3ea84972ed6b4eac22a49fa7b.jpg: 1024x1024 1 car, 1 bus, 81.9ms
# image 63/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_008_jpg.rf.759be3002772eba98dce6c3056eee12e.jpg: 1024x1024 3 cars, 1 rickshaw, 81.8ms
# image 64/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_009_jpg.rf.5d69157a9d3c50c050d9ad709f04ba8e.jpg: 1024x1024 (no detections), 81.8ms
# image 65/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_010_jpg.rf.9bf70d019ae3d0e74921341c4f6eb39c.jpg: 1024x1024 (no detections), 82.7ms
# image 66/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_011_jpg.rf.ce2e974dca04d8dc199c26d60718e370.jpg: 1024x1024 1 rickshaw, 82.0ms
# image 67/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_012_jpg.rf.561006169321b2f2b080e3126ef090cc.jpg: 1024x1024 3 cars, 82.1ms
# image 68/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_013_jpg.rf.8b96ddaaae3068653095f76dee41d4ab.jpg: 1024x1024 1 car, 82.1ms
# image 69/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_014_jpg.rf.64ea0faf233dfae6ff7fc80e3350c906.jpg: 1024x1024 2 cars, 1 motorbike, 82.0ms
# image 70/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_015_jpg.rf.90e353daaaad993d1c60ee502e48793f.jpg: 1024x1024 2 cars, 82.4ms
# image 71/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_016_jpg.rf.08abd5d80a760bc68f94a0752e571adf.jpg: 1024x1024 1 car, 82.2ms
# image 72/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_017_jpg.rf.83b81dc6689db006a7e28526066ae931.jpg: 1024x1024 3 cars, 2 rickshaws, 82.2ms
# image 73/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_018_jpg.rf.1dccfd91443605cf13d0f6150aaf3701.jpg: 1024x1024 2 rickshaws, 82.1ms
# image 74/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_019_jpg.rf.5ba32e81ee93e9ad4722d9d47c0a05fb.jpg: 1024x1024 (no detections), 82.2ms
# image 75/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_020_jpg.rf.deddb99792c580f276d35d5aa50e0247.jpg: 1024x1024 1 rickshaw, 82.0ms
# image 76/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_021_jpg.rf.2ff62c4e14061964fc5b0794d3b5956c.jpg: 1024x1024 (no detections), 82.3ms
# image 77/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_022_jpg.rf.9eba21c6ffdf46cd0c6e58007333491d.jpg: 1024x1024 1 car, 1 bus, 82.0ms
# image 78/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_023_jpg.rf.508364b27060e5c795835253436fe7b8.jpg: 1024x1024 1 car, 82.1ms
# image 79/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_024_jpg.rf.b475e9a7706ce7be83108e15364f8ffd.jpg: 1024x1024 1 car, 1 bus, 82.1ms
# image 80/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_025_jpg.rf.65e10a8033fb8b4fc6ca9ff5dde4ba26.jpg: 1024x1024 1 car, 81.9ms
# image 81/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_026_jpg.rf.e838dc8bdddf0eb1c86ed6b750a37a13.jpg: 1024x1024 3 cars, 82.1ms
# image 82/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_027_jpg.rf.8cff02aee02255a727922bbb08db8de7.jpg: 1024x1024 3 cars, 1 bus, 82.0ms
# image 83/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_028_jpg.rf.ff91047c0de8bd1259c4407b42913c16.jpg: 1024x1024 1 car, 1 bus, 82.4ms
# image 84/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_029_jpg.rf.67af43819cad129b563a84440ba6d0ba.jpg: 1024x1024 2 cars, 1 rickshaw, 1 bus, 82.1ms
# image 85/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_030_jpg.rf.4b789303eddebb18dbf3d4a90c45cc43.jpg: 1024x1024 2 cars, 1 rickshaw, 82.1ms
# image 86/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_031_jpg.rf.fec87f45e45f35180c1f87baaf385e27.jpg: 1024x1024 1 car, 82.2ms
# image 87/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_032_jpg.rf.40307e22dba1f7a1151f2bf33d5fba77.jpg: 1024x1024 3 cars, 82.4ms
# image 88/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_033_jpg.rf.cfee345621a5dd86d203032986197758.jpg: 1024x1024 1 car, 82.2ms
# image 89/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_034_jpg.rf.1fa05bb88511519df963de974436b0b9.jpg: 1024x1024 2 cars, 2 rickshaws, 82.1ms
# image 90/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_035_jpg.rf.1e4d89892a86195aeaac7e1e4288d2c2.jpg: 1024x1024 1 car, 82.0ms
# image 91/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_036_jpg.rf.7dbbd77420a2b4f984290afa9f6d931d.jpg: 1024x1024 2 cars, 2 rickshaws, 82.0ms
# image 92/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_037_jpg.rf.6ef4f3e234ecb26853f1fff805a732ea.jpg: 1024x1024 1 car, 1 rickshaw, 1 bus, 82.2ms
# image 93/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_038_jpg.rf.899054ffaf557de988cb6fc2d7b63647.jpg: 1024x1024 1 car, 1 rickshaw, 82.7ms
# image 94/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_039_jpg.rf.8fb530c27cc6b06853c1a8bdcb34429a.jpg: 1024x1024 2 cars, 1 rickshaw, 82.3ms
# image 95/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_040_jpg.rf.cd4e5b6d204713e99035df01af3ce3f3.jpg: 1024x1024 1 car, 82.2ms
# image 96/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_041_jpg.rf.5a44ab74a39b52f3cbe24df9961c6d66.jpg: 1024x1024 3 cars, 1 rickshaw, 82.2ms
# image 97/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_042_jpg.rf.dee75dbcb561a01cfb6c3b4090869de4.jpg: 1024x1024 2 cars, 1 bus, 82.1ms
# image 98/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_043_jpg.rf.34eb560bf4921fd2d28b015e16f0a6c7.jpg: 1024x1024 1 car, 82.5ms
# image 99/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_044_jpg.rf.c4a654cef9a50e97c37689ffca72e496.jpg: 1024x1024 3 cars, 82.3ms
# image 100/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_045_jpg.rf.219dedd96cdb019ddc5742b5e7e43590.jpg: 1024x1024 5 cars, 1 bus, 1 motorbike, 82.1ms
# image 101/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_046_jpg.rf.5fe6b37ceea6c7ea3c86ace15d61a3ce.jpg: 1024x1024 2 cars, 1 bus, 82.9ms
# image 102/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_047_jpg.rf.d1d60d5ba2acf96060158b929d5c1663.jpg: 1024x1024 1 car, 82.6ms
# image 103/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_048_jpg.rf.9181e8a1ff7e382584eda91d9264dbd5.jpg: 1024x1024 1 car, 82.4ms
# image 104/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_049_jpg.rf.f51ecb9546e5cfcff52edd0e3fc7e3fd.jpg: 1024x1024 1 car, 3 rickshaws, 82.3ms
# image 105/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_050_jpg.rf.da1b698dcac2c2bee634b457408217f1.jpg: 1024x1024 1 car, 2 rickshaws, 82.2ms
# image 106/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_051_jpg.rf.eb5dd25e6ca1768e793952d89c7d2298.jpg: 1024x1024 1 car, 1 rickshaw, 82.2ms
# image 107/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_052_jpg.rf.6390a74ef46c27ea1b424b8f70647cf9.jpg: 1024x1024 1 car, 2 rickshaws, 1 bus, 82.3ms
# image 108/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_02_053_jpg.rf.6c7beca35c4817cc97a42d7086b33669.jpg: 1024x1024 1 rickshaw, 82.0ms
# image 109/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_001_jpg.rf.72fed5da75ff1f936ce31013c67b743c.jpg: 1024x1024 3 cars, 2 rickshaws, 82.1ms
# image 110/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_002_jpg.rf.b69b3f19a9c9cfe5846ee0ba11a64a1c.jpg: 1024x1024 1 car, 1 rickshaw, 82.4ms
# image 111/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_003_jpg.rf.c12a6c7b1f9c75591877fcaa0d28dd20.jpg: 1024x1024 2 cars, 3 rickshaws, 82.1ms
# image 112/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_004_jpg.rf.241fbe224d2d0c208d2fe6540b29f210.jpg: 1024x1024 1 car, 82.4ms
# image 113/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_005_jpg.rf.75c9881a9408452a097f5c467b1453d1.jpg: 1024x1024 1 rickshaw, 82.3ms
# image 114/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_006_jpg.rf.ec80e472ece35fb677e3deb84910eb95.jpg: 1024x1024 2 cars, 1 rickshaw, 82.1ms
# image 115/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_007_jpg.rf.5199efb620d9bc989494ba058d813271.jpg: 1024x1024 2 cars, 2 rickshaws, 2 motorbikes, 82.5ms
# image 116/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_008_jpg.rf.8182379d9d33301768e47b1d54470f85.jpg: 1024x1024 1 car, 1 rickshaw, 83.3ms
# image 117/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_009_jpg.rf.310004a815a9c731c95be3c0c7f333f5.jpg: 1024x1024 1 car, 2 rickshaws, 2 motorbikes, 82.3ms
# image 118/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_010_jpg.rf.f59782fe84e1b6f31c725429c8c56ae1.jpg: 1024x1024 3 cars, 82.1ms
# image 119/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_011_jpg.rf.3e77d56ba223888f368cac88c3acf8aa.jpg: 1024x1024 2 cars, 1 rickshaw, 82.1ms
# image 120/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_012_jpg.rf.6fce47e125dbd88257221b08a4c853d2.jpg: 1024x1024 3 cars, 2 rickshaws, 82.0ms
# image 121/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_013_jpg.rf.fb52429de27b0bfe94fe5e714d7e7964.jpg: 1024x1024 1 car, 2 rickshaws, 82.7ms
# image 122/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_014_jpg.rf.29404b71284ea2d6d2b6a2e0ff9832d7.jpg: 1024x1024 1 car, 1 bus, 82.1ms
# image 123/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_015_jpg.rf.76648269ab211cc7face25e4a2f4625a.jpg: 1024x1024 1 car, 1 rickshaw, 82.4ms
# image 124/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_016_jpg.rf.a31fff1a8542ed21a6d69bfc77c1138e.jpg: 1024x1024 2 cars, 3 rickshaws, 2 buss, 82.3ms
# image 125/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_017_jpg.rf.05db837b483b8caf4c62cb5182edc4d6.jpg: 1024x1024 3 cars, 1 rickshaw, 82.5ms
# image 126/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_018_jpg.rf.7e2ec54d96b0910ec8c5dbf65d8f6810.jpg: 1024x1024 4 cars, 1 rickshaw, 82.4ms
# image 127/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_019_jpg.rf.a15348853c7d382bac9d7acc863d4fb1.jpg: 1024x1024 1 car, 1 rickshaw, 81.9ms
# image 128/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_020_jpg.rf.2c08536baee46b775b842fdc45a36cb7.jpg: 1024x1024 2 cars, 3 rickshaws, 82.1ms
# image 129/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_021_jpg.rf.ea765bce0bb3ae9dc6c298b96c7a2874.jpg: 1024x1024 3 cars, 1 rickshaw, 82.2ms
# image 130/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_022_jpg.rf.125217f8cc669e5ec6938d17777838c6.jpg: 1024x1024 4 cars, 1 bus, 82.4ms
# image 131/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_023_jpg.rf.a443eee6c1a35f2a07d69c8e5f79125c.jpg: 1024x1024 1 car, 1 bus, 82.8ms
# image 132/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_024_jpg.rf.5712fdb47693e33c7901dc8f043bbdf1.jpg: 1024x1024 1 car, 1 rickshaw, 82.6ms
# image 133/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_025_jpg.rf.236f3bd3394f66974e29eb03dc89904e.jpg: 1024x1024 2 cars, 82.1ms
# image 134/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_026_jpg.rf.0462fe3e9e3f2abf897db8c46e5e395e.jpg: 1024x1024 1 car, 1 motorbike, 82.1ms
# image 135/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_027_jpg.rf.ba2c5601801b6d4d17bd56e0ec41e8e9.jpg: 1024x1024 1 car, 82.2ms
# image 136/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_028_jpg.rf.5e8d585a92a192ca9b045ca8d949ba79.jpg: 1024x1024 3 cars, 82.1ms
# image 137/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_029_jpg.rf.d5d2fa2965abd6d1d7dc2b5f7488d8b9.jpg: 1024x1024 4 cars, 82.2ms
# image 138/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_030_jpg.rf.38827a40876a613fc278cd6028f94922.jpg: 1024x1024 2 cars, 82.2ms
# image 139/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_031_jpg.rf.ccb85b949ca20c796251a2a69bbf5b61.jpg: 1024x1024 4 cars, 1 rickshaw, 1 bus, 82.3ms
# image 140/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_032_jpg.rf.81ed7c4cea1b4320230a275fe5f8c1b0.jpg: 1024x1024 6 cars, 82.2ms
# image 141/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_033_jpg.rf.f50f8cb18fdcc9cdf3fa9256779fc411.jpg: 1024x1024 1 car, 2 rickshaws, 82.0ms
# image 142/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_034_jpg.rf.ffe71fb6021b14dfd533420a59d91469.jpg: 1024x1024 1 car, 82.3ms
# image 143/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_035_jpg.rf.a18bc338a0cc9620d4fdef308d33c2b5.jpg: 1024x1024 2 cars, 82.3ms
# image 144/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_03_036_jpg.rf.0cf05b47c15ea096e609d8bdbd7b97c9.jpg: 1024x1024 4 rickshaws, 82.0ms
# image 145/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (1)_jpg.rf.229bebbe15b12cf1834b38a9a574a8ac.jpg: 1024x1024 1 car, 1 rickshaw, 81.9ms
# image 146/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (10)_jpg.rf.029f4c991081a75e9714ce551a622e6f.jpg: 1024x1024 1 car, 1 motorbike, 81.9ms
# image 147/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (11)_jpg.rf.35080f7fe5c665674eb04290f0df1f8d.jpg: 1024x1024 1 rickshaw, 1 bus, 3 motorbikes, 82.6ms
# image 148/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (13)_jpg.rf.987c7fb1045e8a757ca5740dea508c7b.jpg: 1024x1024 2 cars, 83.2ms
# image 149/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (14)_jpg.rf.c807d36f832e418f6106ec5f1d2dd016.jpg: 1024x1024 2 cars, 82.6ms
# image 150/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (15)_jpg.rf.8e1c8b362b70272d33964e579c4af3b7.jpg: 1024x1024 1 motorbike, 82.4ms
# image 151/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (16)_jpg.rf.44c778a0bae5d189ce4ea4e1e11f4086.jpg: 1024x1024 2 cars, 1 rickshaw, 1 motorbike, 82.0ms
# image 152/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (17)_jpg.rf.e8574afde922d2ce3c9738db301cf8b2.jpg: 1024x1024 1 car, 1 rickshaw, 82.3ms
# image 153/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (18)_jpg.rf.1c555f498cf3cfe00f71c4dcba5739fa.jpg: 1024x1024 1 car, 2 rickshaws, 82.4ms
# image 154/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (2)_jpg.rf.467be143ff078021badd137f5368b7e7.jpg: 1024x1024 1 rickshaw, 1 motorbike, 82.4ms
# image 155/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (20)_jpg.rf.8be7c8761be454ef2ee25f81637c555a.jpg: 1024x1024 1 car, 1 rickshaw, 1 motorbike, 82.2ms
# image 156/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (21)_jpg.rf.a17df77897d17763c43325b32e69bf76.jpg: 1024x1024 2 rickshaws, 82.2ms
# image 157/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (22)_jpg.rf.9e93bd4798cf7d3dd4a46e43dc10577e.jpg: 1024x1024 1 rickshaw, 82.4ms
# image 158/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (23)_jpg.rf.c29fba7c4c2b0d2ee12795587ded84e8.jpg: 1024x1024 1 car, 82.8ms
# image 159/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (24)_jpg.rf.4f7b1d3e1be5e28dd863f370f8d025a8.jpg: 1024x1024 1 car, 1 motorbike, 82.5ms
# image 160/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (25)_jpg.rf.def5fcdded216045930b4146054c9dc0.jpg: 1024x1024 1 car, 1 rickshaw, 1 motorbike, 82.5ms
# image 161/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (26)_jpg.rf.0667cc7161865a93baf6f3a099cf0afb.jpg: 1024x1024 2 cars, 1 motorbike, 82.3ms
# image 162/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (27)_jpg.rf.188df387d9f01b635d9b75bc7644b7a4.jpg: 1024x1024 1 car, 82.4ms
# image 163/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (28)_jpg.rf.c057111062d7a008142e120963471e17.jpg: 1024x1024 1 car, 2 rickshaws, 1 motorbike, 82.6ms
# image 164/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (29)_jpg.rf.4a65172449fd48a43404d8ceb5a0cfdc.jpg: 1024x1024 2 cars, 1 rickshaw, 82.8ms
# image 165/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (3)_jpg.rf.74da0a1dfaaf056fabc4b0d6e93f9589.jpg: 1024x1024 1 car, 1 rickshaw, 1 motorbike, 82.6ms
# image 166/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (30)_jpg.rf.3c868926b4f2eaead275d7fb2dd88483.jpg: 1024x1024 1 rickshaw, 1 motorbike, 82.2ms
# image 167/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (31)_jpg.rf.a4116e8573e0a7d37e6047d205cfef23.jpg: 1024x1024 1 rickshaw, 1 motorbike, 82.3ms
# image 168/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (32)_jpg.rf.8446260299fe896c44e8c291d3e2c976.jpg: 1024x1024 1 rickshaw, 82.0ms
# image 169/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (33)_jpg.rf.c1ce8994e855d090ec1930b9eb013855.jpg: 1024x1024 1 rickshaw, 1 motorbike, 82.4ms
# image 170/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (34)_jpg.rf.1bf1d076b872c4f2834b4bcc8f9feec9.jpg: 1024x1024 2 rickshaws, 82.4ms
# image 171/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (35)_jpg.rf.e4f936fdd85ef9be751464be25a9170a.jpg: 1024x1024 1 motorbike, 82.2ms
# image 172/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (36)_jpg.rf.009b7a209c900850c728b8b11a7d7477.jpg: 1024x1024 1 car, 1 motorbike, 82.2ms
# image 173/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (37)_jpg.rf.eca2fbb4540d96a0d9fcde21cc9c016c.jpg: 1024x1024 1 car, 1 bus, 1 motorbike, 82.2ms
# image 174/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (38)_jpg.rf.ba37ea66565b63f9211404a127ecd9cd.jpg: 1024x1024 (no detections), 82.8ms
# image 175/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (39)_jpg.rf.c57524355aeca23e0c2ab2cda25aaa5c.jpg: 1024x1024 1 bus, 83.3ms
# image 176/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (4)_jpg.rf.e2cb0462a1bb28ab5904e0f84b2f3683.jpg: 1024x1024 3 cars, 83.2ms
# image 177/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (40)_jpg.rf.cbdabe292998c7d85f4e20d63f54762c.jpg: 1024x1024 1 car, 3 rickshaws, 1 motorbike, 82.8ms
# image 178/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (41)_jpg.rf.a19bdb9d289d2e640bdcf6360209c8c9.jpg: 1024x1024 1 car, 1 rickshaw, 1 motorbike, 82.6ms
# image 179/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (42)_jpg.rf.fc459f2f288e938572889a86875a7d1b.jpg: 1024x1024 3 cars, 83.3ms
# image 180/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (43)_jpg.rf.457ec12ec835929047e4c011e9361e9b.jpg: 1024x1024 (no detections), 82.4ms
# image 181/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (44)_jpg.rf.7d83b5182d343c33b29c96b01d3ca94d.jpg: 1024x1024 1 motorbike, 82.4ms
# image 182/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (45)_jpg.rf.7b1240080bbc30abc598256f3e3ce5f4.jpg: 1024x1024 1 car, 1 bus, 2 motorbikes, 82.7ms
# image 183/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (46)_jpg.rf.9be3149ed8c223f006fbc161ae6729c6.jpg: 1024x1024 1 car, 1 bus, 2 motorbikes, 82.1ms
# image 184/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (47)_jpg.rf.fa40bcaefb6887416db98b424ca9bf0a.jpg: 1024x1024 1 bus, 1 motorbike, 83.0ms
# image 185/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (49)_jpg.rf.81d278a881bf0991c44bd40c4db0cd7d.jpg: 1024x1024 1 rickshaw, 1 motorbike, 82.9ms
# image 186/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (5)_jpg.rf.33e158aa1af9e774c7df0c9f50219140.jpg: 1024x1024 (no detections), 82.5ms
# image 187/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (50)_jpg.rf.2e08af2776407f6449bcfc37c532acbd.jpg: 1024x1024 1 motorbike, 82.1ms
# image 188/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (51)_jpg.rf.c207bdaf5fed52e1d10c6a6451d5f360.jpg: 1024x1024 1 motorbike, 82.8ms
# image 189/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (52)_jpg.rf.bcb9c773a2e8a8ea6dfc069254b6318b.jpg: 1024x1024 1 rickshaw, 1 bus, 1 motorbike, 82.2ms
# image 190/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (53)_jpg.rf.8e5773d27fe7d257fd66ad864f2e353b.jpg: 1024x1024 1 rickshaw, 1 bus, 82.9ms
# image 191/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (54)_jpg.rf.984baf98c77ab33fa330afb78ac9aef5.jpg: 1024x1024 1 rickshaw, 1 motorbike, 83.0ms
# image 192/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (55)_jpg.rf.396af2ea9b6af033f403a2eee01c59ab.jpg: 1024x1024 1 rickshaw, 83.2ms
# image 193/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (56)_jpg.rf.85328f260f4fd2dac884b376a2686480.jpg: 1024x1024 1 bus, 1 motorbike, 82.3ms
# image 194/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (57)_jpg.rf.b2cd5a72f50ea6917163bbb35aa0e2fb.jpg: 1024x1024 1 bus, 1 motorbike, 82.7ms
# image 195/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (58)_jpg.rf.a63e37d0b3e431915699531ec54462e1.jpg: 1024x1024 (no detections), 82.4ms
# image 196/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (59)_jpg.rf.baec676071651b7febaccebf0b7a5e74.jpg: 1024x1024 2 motorbikes, 82.3ms
# image 197/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (60)_jpg.rf.5951263d9539cefc3316b50725dda23a.jpg: 1024x1024 1 bus, 82.1ms
# image 198/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (61)_jpg.rf.0b5df937ad66e8f79809e548ee2953af.jpg: 1024x1024 1 car, 2 rickshaws, 1 bus, 1 motorbike, 82.1ms
# image 199/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (7)_jpg.rf.fa43c09d1601aa7a8e27196e49f09eed.jpg: 1024x1024 2 rickshaws, 2 motorbikes, 82.2ms
# image 200/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (8)_jpg.rf.e3902798d07936d88d0bd243db7f8c59.jpg: 1024x1024 2 buss, 82.3ms
# image 201/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_4_ (9)_jpg.rf.b1c63e89bf3a0c01f8c3226662bb74c6.jpg: 1024x1024 1 rickshaw, 81.9ms
# image 202/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (1)_jpg.rf.63e70e2cf04c95242defe4ae9ea09376.jpg: 1024x1024 3 cars, 5 rickshaws, 1 motorbike, 82.7ms
# image 203/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (10)_jpg.rf.9d9ddef634833519150980eeb67524e7.jpg: 1024x1024 1 car, 82.1ms
# image 204/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (100)_jpg.rf.d817b031b3c6f0f209aaecbd05cd353a.jpg: 1024x1024 1 car, 1 bus, 82.3ms
# image 205/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (101)_jpg.rf.f1b730d702a75e9a0f640c715179f625.jpg: 1024x1024 2 cars, 1 rickshaw, 82.6ms
# image 206/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (102)_jpg.rf.4009aa50d8072132b31934ff3e83be7f.jpg: 1024x1024 1 rickshaw, 82.3ms
# image 207/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (103)_jpg.rf.ae65f96066b94c2e0387557024b61eef.jpg: 1024x1024 1 car, 82.4ms
# image 208/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (104)_jpg.rf.2621e379b16f2d79fd97c2be9daa177d.jpg: 1024x1024 2 cars, 82.4ms
# image 209/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (105)_jpg.rf.99cb493062f0acfcdfbf855727e531f8.jpg: 1024x1024 2 cars, 1 rickshaw, 82.7ms
# image 210/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (106)_jpg.rf.dfb4bdb5e653b3e2af95165a8622c3c1.jpg: 1024x1024 1 car, 1 bus, 82.3ms
# image 211/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (107)_jpg.rf.1df0bc755f98fc02def0a242e747fef4.jpg: 1024x1024 1 car, 1 rickshaw, 82.0ms
# image 212/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (108)_jpg.rf.363bdd32cc2c99f2c5224c1f8ac54256.jpg: 1024x1024 3 cars, 82.5ms
# image 213/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (109)_jpg.rf.77a0658d2fe975b8a0f31c0f33ac92ff.jpg: 1024x1024 1 rickshaw, 82.1ms
# image 214/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (11)_jpg.rf.8576f9d54c38d81b25a8c1aef34ec9fe.jpg: 1024x1024 1 rickshaw, 82.4ms
# image 215/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (110)_jpg.rf.71606778c62285beb0cdb0ab3480680c.jpg: 1024x1024 (no detections), 82.2ms
# image 216/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (111)_jpg.rf.573e8d0186fed28a4a375016eeda0e31.jpg: 1024x1024 3 cars, 1 rickshaw, 1 motorbike, 81.9ms
# image 217/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (112)_jpg.rf.aec652362d67b6c6229903dc53763466.jpg: 1024x1024 1 car, 1 rickshaw, 81.7ms
# image 218/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (113)_jpg.rf.1d22d7b62dd7c899ecc544a7ac6340be.jpg: 1024x1024 1 car, 1 bus, 82.3ms
# image 219/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (114)_jpg.rf.033a055e17aca4d9bef1d9df1a4b105a.jpg: 1024x1024 1 car, 1 rickshaw, 5 buss, 82.1ms
# image 220/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (115)_jpg.rf.c50a96f50416b4ad42256b0ecce7bd54.jpg: 1024x1024 1 car, 82.0ms
# image 221/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (116)_jpg.rf.02482eba9f98c6320111c94474e39d64.jpg: 1024x1024 (no detections), 82.1ms
# image 222/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (12)_jpg.rf.4b9516dca1e555b7ef52a3e0ae3d3000.jpg: 1024x1024 (no detections), 82.1ms
# image 223/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (13)_jpg.rf.981ecd97102b874671a916f4283a2181.jpg: 1024x1024 1 rickshaw, 81.9ms
# image 224/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (14)_jpg.rf.4b2383070e0446ce1a10a3526ebe7105.jpg: 1024x1024 1 car, 2 rickshaws, 1 motorbike, 82.9ms
# image 225/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (15)_jpg.rf.c0508776a64778170e7f71c95db370e5.jpg: 1024x1024 1 car, 2 rickshaws, 82.0ms
# image 226/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (16)_jpg.rf.d156f9d32965166f407c462ce49273ad.jpg: 1024x1024 1 rickshaw, 82.2ms
# image 227/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (17)_jpg.rf.bd73a177830e16e7ff7b0327b157744c.jpg: 1024x1024 1 car, 1 rickshaw, 82.0ms
# image 228/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (18)_jpg.rf.e9ca17d32e399a2f0a35aa502040b0c0.jpg: 1024x1024 1 car, 82.0ms
# image 229/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (19)_jpg.rf.affed6021cd3eaa6759fdda17bf47464.jpg: 1024x1024 1 car, 1 rickshaw, 81.9ms
# image 230/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (2)_jpg.rf.ed805fa1c83ffebaeaee81c35a6baae3.jpg: 1024x1024 (no detections), 82.3ms
# image 231/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (20)_jpg.rf.693f35dca92b8f7f98b60d53071a4d7b.jpg: 1024x1024 1 car, 82.4ms
# image 232/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (21)_jpg.rf.11b91aca443437c99fed5e1d5d0285e5.jpg: 1024x1024 1 car, 82.1ms
# image 233/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (22)_jpg.rf.414cda0320c928405688e00faea36d92.jpg: 1024x1024 1 rickshaw, 1 bus, 82.3ms
# image 234/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (23)_jpg.rf.caac130cf9ba5b838edea1140105d146.jpg: 1024x1024 1 rickshaw, 82.2ms
# image 235/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (24)_jpg.rf.f69250d63e462a5e7f9038e0d3d049f7.jpg: 1024x1024 1 car, 1 rickshaw, 81.9ms
# image 236/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (25)_jpg.rf.222eb66e904949416d43e48ac32bbcb1.jpg: 1024x1024 2 cars, 82.4ms
# image 237/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (26)_jpg.rf.ba65346f661201e7ce5aeb5d2e0e1c02.jpg: 1024x1024 1 car, 82.7ms
# image 238/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (27)_jpg.rf.9e95d569998da1fd2058cc358692c685.jpg: 1024x1024 1 car, 82.4ms
# image 239/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (28)_jpg.rf.54734e64d93f5311efa478458d981015.jpg: 1024x1024 1 car, 82.3ms
# image 240/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (29)_jpg.rf.3adc55a19d6e961cd3de238a0297af7e.jpg: 1024x1024 1 bus, 82.4ms
# image 241/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (3)_jpg.rf.0448dd6ebc43fd8fc4d2d2f8d0a9dc9b.jpg: 1024x1024 4 cars, 1 rickshaw, 82.4ms
# image 242/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (30)_jpg.rf.047518189bd496eeb0cf37b589dd8cf9.jpg: 1024x1024 1 car, 82.3ms
# image 243/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (31)_jpg.rf.f5fb2ad215629e04daf4f7477af31ba5.jpg: 1024x1024 2 cars, 1 rickshaw, 82.5ms
# image 244/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (32)_jpg.rf.1e60f4a9166d64426f5b859b585372c3.jpg: 1024x1024 1 car, 82.6ms
# image 245/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (33)_jpg.rf.a28d85ba69ed33824a3ae2d7675da2f7.jpg: 1024x1024 1 bus, 82.1ms
# image 246/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (34)_jpg.rf.bf7a7ca319fa7430a13b2eeddc2196d6.jpg: 1024x1024 1 car, 1 bus, 82.2ms
# image 247/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (35)_jpg.rf.fec3ce8133a7bce139e318b6e0227bb8.jpg: 1024x1024 1 car, 82.0ms
# image 248/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (36)_jpg.rf.4871460962c5f537376e1ad5b882344a.jpg: 1024x1024 3 cars, 81.6ms
# image 249/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (37)_jpg.rf.ac70c67614d3be943ba2fbf19a3ffff8.jpg: 1024x1024 3 cars, 1 rickshaw, 82.3ms
# image 250/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (38)_jpg.rf.56057748e57a7617af67873d735d77fd.jpg: 1024x1024 1 car, 83.0ms
# image 251/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (39)_jpg.rf.b283e9d1cc3e3db1f0654103352c6a46.jpg: 1024x1024 2 cars, 2 rickshaws, 82.3ms
# image 252/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (4)_jpg.rf.ab6728249aafcfbc8959e6f4411f8e5b.jpg: 1024x1024 3 cars, 4 rickshaws, 82.2ms
# image 253/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (40)_jpg.rf.2cfa911b9a9f1c9c835fd1ba06211321.jpg: 1024x1024 2 cars, 1 bus, 82.4ms
# image 254/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (41)_jpg.rf.bb85851b65fe1b435153de4d826b96d7.jpg: 1024x1024 1 car, 1 rickshaw, 1 bus, 82.0ms
# image 255/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (42)_jpg.rf.b9c0eaf47758f42ac76cfb5fc0520c29.jpg: 1024x1024 1 car, 1 rickshaw, 1 bus, 82.1ms
# image 256/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (43)_jpg.rf.dd629532ef4a8b7e85211b6a0ec0a4b1.jpg: 1024x1024 2 rickshaws, 82.3ms
# image 257/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (44)_jpg.rf.79fa6df6074d69e1e09e78447dc67190.jpg: 1024x1024 1 car, 3 rickshaws, 82.7ms
# image 258/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (45)_jpg.rf.4da180b1831613246ae86a5663e5543c.jpg: 1024x1024 2 rickshaws, 82.6ms
# image 259/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (46)_jpg.rf.bef182a1f0c4a9c6cef9f0178a62626a.jpg: 1024x1024 3 rickshaws, 82.2ms
# image 260/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (47)_jpg.rf.6a9844ee2521d42cdf292c02c34054f0.jpg: 1024x1024 2 rickshaws, 82.2ms
# image 261/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (48)_jpg.rf.cd0ac31f33fc69f1b78403dc9f9a938f.jpg: 1024x1024 2 rickshaws, 82.1ms
# image 262/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (49)_jpg.rf.007d8ccdf8fb0907fd9ee1f34fdd4f4d.jpg: 1024x1024 3 cars, 1 rickshaw, 82.1ms
# image 263/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (5)_jpg.rf.576ef3ff2daa7a6b5fce7557950f1444.jpg: 1024x1024 2 cars, 2 rickshaws, 82.3ms
# image 264/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (50)_jpg.rf.479b2a5dbc0830cd90181bed3ca346b9.jpg: 1024x1024 1 rickshaw, 82.2ms
# image 265/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (51)_jpg.rf.3b55810b21b62ed2021bd80c26d41cf7.jpg: 1024x1024 1 rickshaw, 1 bus, 82.0ms
# image 266/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (52)_jpg.rf.3e100b0ae1f610d0be46416dbd35add6.jpg: 1024x1024 1 car, 1 rickshaw, 82.2ms
# image 267/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (53)_jpg.rf.22bb9fe33d3616f67d55d7aa5eb68c35.jpg: 1024x1024 1 rickshaw, 82.1ms
# image 268/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (54)_jpg.rf.0d5886ce1d1e71c3522957da635b1062.jpg: 1024x1024 2 rickshaws, 83.5ms
# image 269/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (55)_jpg.rf.321cf368a67e7ceaed83975f4839b4d5.jpg: 1024x1024 2 cars, 82.2ms
# image 270/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (56)_jpg.rf.8942f973923b65f8d6f0e598668cee97.jpg: 1024x1024 2 rickshaws, 82.2ms
# image 271/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (57)_jpg.rf.06bd48db40ff300ea711f48b9cd5b193.jpg: 1024x1024 1 car, 82.2ms
# image 272/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (58)_jpg.rf.b66a00cda2ec3503133ce7d7f79a5e33.jpg: 1024x1024 (no detections), 81.9ms
# image 273/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (59)_jpg.rf.37848c9699fd6e1f13c02bb9cc0a73e6.jpg: 1024x1024 1 bus, 82.7ms
# image 274/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (6)_jpg.rf.2a4c61f67bb684ade6cb263483249bf5.jpg: 1024x1024 1 car, 3 rickshaws, 82.4ms
# image 275/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (60)_jpg.rf.8d73d8fed3e04eb3df66e7a3a1c7f265.jpg: 1024x1024 (no detections), 82.4ms
# image 276/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (61)_jpg.rf.460f3cb61fe54110a1f7062d1f5b2d09.jpg: 1024x1024 1 rickshaw, 1 motorbike, 82.0ms
# image 277/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (62)_jpg.rf.7aee904ccde54793c070f2bab84803fd.jpg: 1024x1024 1 car, 4 rickshaws, 1 bus, 82.3ms
# image 278/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (63)_jpg.rf.c731072660225d8276ff1bd0f17bb7e4.jpg: 1024x1024 2 rickshaws, 1 bus, 82.2ms
# image 279/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (64)_jpg.rf.6e16a7cab17e310481abe9635f5afa47.jpg: 1024x1024 1 car, 1 bus, 82.2ms
# image 280/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (65)_jpg.rf.9a095c5c11e44e6a3d1b1c5abb2b6309.jpg: 1024x1024 2 cars, 82.7ms
# image 281/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (66)_jpg.rf.47efae3700f99f8cdcca4e93d053589d.jpg: 1024x1024 2 cars, 1 rickshaw, 82.2ms
# image 282/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (67)_jpg.rf.555d7737349390a45ca3fe7ac8b5ce19.jpg: 1024x1024 1 car, 1 rickshaw, 1 bus, 82.2ms
# image 283/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (68)_jpg.rf.5718dea3dcb99362d60f5e4a360fb54c.jpg: 1024x1024 5 cars, 1 rickshaw, 1 bus, 82.4ms
# image 284/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (69)_jpg.rf.b54c84a84a6c91927b5afba60c0dd0e3.jpg: 1024x1024 1 car, 1 motorbike, 82.0ms
# image 285/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (7)_jpg.rf.500a7fb1705b9525167bb53eac898070.jpg: 1024x1024 3 rickshaws, 82.9ms
# image 286/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (70)_jpg.rf.1f4660be88f887a63862511fbd73c54e.jpg: 1024x1024 1 car, 2 buss, 83.9ms
# image 287/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (71)_jpg.rf.0a5531ccddf1a47cbf0a0a3aa96b06c0.jpg: 1024x1024 1 car, 82.4ms
# image 288/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (72)_jpg.rf.e0a3eb2c461f3f53f90b5b7406625d7c.jpg: 1024x1024 1 car, 82.1ms
# image 289/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (73)_jpg.rf.b0af436f95df90c661739e17584f8fe3.jpg: 1024x1024 4 cars, 1 rickshaw, 82.0ms
# image 290/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (74)_jpg.rf.88159784074b68691c229683aaa13704.jpg: 1024x1024 2 cars, 2 rickshaws, 2 buss, 82.1ms
# image 291/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (75)_jpg.rf.38b18bc2d862399072bd1b66cd942995.jpg: 1024x1024 2 cars, 1 rickshaw, 3 buss, 82.2ms
# image 292/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (76)_jpg.rf.440799c009634a91033f13b214b0729b.jpg: 1024x1024 (no detections), 82.6ms
# image 293/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (77)_jpg.rf.e0b47bbb9b532687388ba9af2b2d3727.jpg: 1024x1024 1 rickshaw, 1 bus, 82.1ms
# image 294/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (78)_jpg.rf.ab143ddabf2c769cd5e7434fbd54b113.jpg: 1024x1024 1 rickshaw, 1 bus, 82.1ms
# image 295/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (79)_jpg.rf.d2a2fe8d33717021f2a2dd0803cba759.jpg: 1024x1024 (no detections), 82.1ms
# image 296/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (8)_jpg.rf.853ada80c08d576fa54388c48fb7bfdf.jpg: 1024x1024 2 cars, 1 rickshaw, 81.8ms
# image 297/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (80)_jpg.rf.b7705efab4913eba4679ace40a0bb399.jpg: 1024x1024 1 car, 82.0ms
# image 298/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (81)_jpg.rf.6b4b5947f8b4f4940703cd2ac9156623.jpg: 1024x1024 1 car, 1 rickshaw, 82.5ms
# image 299/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (82)_jpg.rf.f9ebdd8a5e7627628dc6b4a7fb688419.jpg: 1024x1024 2 cars, 82.1ms
# image 300/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (83)_jpg.rf.9b04768c6242a31569c333d3223daf7b.jpg: 1024x1024 1 car, 2 rickshaws, 82.1ms
# image 301/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (84)_jpg.rf.490f1b051d6cbf286cce883214e99cde.jpg: 1024x1024 1 car, 3 rickshaws, 3 buss, 82.3ms
# image 302/500 /kaggle/input/vehicle-detection-dataset/test1/test/Shykat_5_ (85)_jpg.rf.f3ecdae9b3b74a86accb1efb7b8fd66d.jpg: 1024x1024 2 cars, 2 rickshaws, 2 buss, 1 motorbike, 82.5ms
# ...
# image 403/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(211)_jpg.rf.83db11272a5a56242934163b6af982e4.jpg: 1024x1024 3 cars, 1 bus, 82.0ms
# image 404/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(212)_jpg.rf.7e503a44fcc7ee0d5c672a278d09d497.jpg: 1024x1024 1 car, 2 rickshaws, 2 buss, 1 motorbike, 82.2ms
# image 405/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(213)_jpg.rf.b7581c97308c651ac437829e21187f4b.jpg: 1024x1024 1 car, 1 rickshaw, 3 buss, 82.2ms
# image 406/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(214)_jpg.rf.b30437ee0cb1d606f6b92c00de60226a.jpg: 1024x1024 2 cars, 2 rickshaws, 1 motorbike, 82.0ms
# image 407/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(215)_jpg.rf.4b4fbba8c4633296885b912a5ed96344.jpg: 1024x1024 1 car, 82.9ms
# image 408/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(216)_jpg.rf.5d27346a36a96740faf0ee618552d435.jpg: 1024x1024 1 car, 82.3ms
# image 409/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(217)_jpg.rf.54d810b7bf37793f9ba3940005f26a8c.jpg: 1024x1024 1 car, 82.2ms
# image 410/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(218)_jpg.rf.0a07c8c9db922047b71b619cbc80d021.jpg: 1024x1024 1 rickshaw, 1 bus, 82.1ms
# image 411/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(219)_jpg.rf.b942e8a426cc363ac26410c9ca06d7f5.jpg: 1024x1024 1 car, 1 rickshaw, 82.0ms
# image 412/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(220)_jpg.rf.1849713d054781b9d7403cddfbd57385.jpg: 1024x1024 2 cars, 81.9ms
# image 413/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(221)_jpg.rf.55382b670de397e8c2b96d753bf94d96.jpg: 1024x1024 1 car, 82.1ms
# image 414/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(222)_jpg.rf.4eac8e3b730dafc1b2acf62d6e7e32b3.jpg: 1024x1024 2 cars, 1 rickshaw, 82.3ms
# image 415/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(223)_jpg.rf.7c6820856be7653f206ed4a545497c90.jpg: 1024x1024 1 car, 1 rickshaw, 82.2ms
# image 416/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(224)_jpg.rf.0db88352cc38f0c2dc82c415b67f243f.jpg: 1024x1024 2 cars, 1 rickshaw, 82.4ms
# image 417/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(225)_jpg.rf.4fd7a2c3ec5d19d30246ce2c50051aaa.jpg: 1024x1024 2 cars, 2 rickshaws, 82.3ms
# image 418/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(226)_jpg.rf.932b1c950477447deffc4f9b0f987f96.jpg: 1024x1024 2 cars, 1 rickshaw, 1 bus, 82.7ms
# image 419/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(227)_jpg.rf.606b929a310db4c7db6d9865243cd98f.jpg: 1024x1024 (no detections), 82.5ms
# image 420/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(228)_jpg.rf.fbdcf736c2da75a60f23f696d4dfa768.jpg: 1024x1024 1 rickshaw, 1 bus, 82.6ms
# image 421/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(229)_jpg.rf.73a119066f17d7fa208da2953d0e4a43.jpg: 1024x1024 1 rickshaw, 1 bus, 82.1ms
# image 422/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(230)_jpg.rf.487bc229b509d6cbe85d2c4cb3baf69d.jpg: 1024x1024 1 car, 3 rickshaws, 1 bus, 82.1ms
# image 423/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(231)_jpg.rf.ce0fa89f3da4d834e7ba276bc6c2d2b9.jpg: 1024x1024 1 car, 3 rickshaws, 1 bus, 82.1ms
# image 424/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(232)_jpg.rf.75477618b50c16a27d6cdd873b0ca04b.jpg: 1024x1024 3 rickshaws, 1 bus, 82.3ms
# image 425/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(233)_jpg.rf.cdd0c3d4a8d6fe9af5adfe1f85f7c40d.jpg: 1024x1024 4 rickshaws, 1 bus, 82.2ms
# image 426/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(234)_jpg.rf.0b4a7fb02b589761a96d5918ecef8239.jpg: 1024x1024 1 bus, 82.6ms
# image 427/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(235)_jpg.rf.ccbaff9882d3ca48873640bba679e404.jpg: 1024x1024 1 car, 1 bus, 82.3ms
# image 428/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(236)_jpg.rf.c84245eac06b43d5768a8bdf2cdb888f.jpg: 1024x1024 1 car, 1 bus, 82.1ms
# image 429/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(237)_jpg.rf.c4813cc323102524b2016e955a4ea722.jpg: 1024x1024 1 car, 82.1ms
# image 430/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(238)_jpg.rf.a2c5c2a92aefb10b38a0635fa455404c.jpg: 1024x1024 1 car, 82.1ms
# image 431/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(239)_jpg.rf.896fee6912f6b9353fda2c5baeb58651.jpg: 1024x1024 1 car, 82.6ms
# image 432/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(240)_jpg.rf.6b1d1573b14e5ad7c7265d15d5c97b10.jpg: 1024x1024 1 car, 4 rickshaws, 1 bus, 1 motorbike, 82.9ms
# image 433/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(241)_jpg.rf.fd2c8189c9e0d74ffc8b34c85aa3ddca.jpg: 1024x1024 4 cars, 6 rickshaws, 82.2ms
# image 434/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(242)_jpg.rf.50a8a3738a054a1cc73a6dacc1f326b6.jpg: 1024x1024 3 cars, 4 rickshaws, 1 bus, 82.3ms
# image 435/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(243)_jpg.rf.6b0da507100d0c6e68d75a73ac19b362.jpg: 1024x1024 2 cars, 3 rickshaws, 82.3ms
# image 436/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(244)_jpg.rf.b987135ce5490e7d73429fa4688c1112.jpg: 1024x1024 1 car, 1 rickshaw, 1 bus, 82.1ms
# image 437/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(245)_jpg.rf.153039c6a25aa1779a7717a74e78dcd6.jpg: 1024x1024 1 car, 2 rickshaws, 1 bus, 82.3ms
# image 438/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(246)_jpg.rf.17b86bb87a80588f2a2f4007faefd877.jpg: 1024x1024 1 bus, 82.5ms
# image 439/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(247)_jpg.rf.1035a27c9dcf576335244bea53ca8b47.jpg: 1024x1024 1 bus, 82.2ms
# image 440/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(248)_jpg.rf.63fb54b5dd5fb81c469a17cad22cd222.jpg: 1024x1024 1 rickshaw, 1 bus, 82.2ms
# image 441/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(249)_jpg.rf.d8f697d90eecd230840b7c72cc043b16.jpg: 1024x1024 1 bus, 82.3ms
# image 442/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(250)_jpg.rf.c9f97cb769a490373f6e3a1748b42e26.jpg: 1024x1024 (no detections), 82.4ms
# image 443/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(251)_jpg.rf.55f65f1f75de1cd84b44d8a10ac1b615.jpg: 1024x1024 (no detections), 82.3ms
# image 444/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(252)_jpg.rf.00cd9a169d4de43b8967a68f02d2c12c.jpg: 1024x1024 1 rickshaw, 82.6ms
# image 445/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(253)_jpg.rf.71e0775df00bb2bc80ca21dedbab098a.jpg: 1024x1024 1 rickshaw, 82.4ms
# image 446/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(254)_jpg.rf.aace5808919df1921d4796357f11398e.jpg: 1024x1024 1 rickshaw, 82.0ms
# image 447/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(255)_jpg.rf.e0ee9a6c602ff4e9af262b9e26be9891.jpg: 1024x1024 2 rickshaws, 82.1ms
# image 448/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(256)_jpg.rf.f72a769c9b64a31f3a0bf741fe495d4b.jpg: 1024x1024 2 rickshaws, 82.0ms
# image 449/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(257)_jpg.rf.e0c7a79b33940a377d466f077f3680e8.jpg: 1024x1024 4 rickshaws, 82.2ms
# image 450/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(258)_jpg.rf.c2c6e3e37c7d055caa91e5a25c16c23e.jpg: 1024x1024 1 car, 2 rickshaws, 82.3ms
# image 451/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(259)_jpg.rf.4968c7968d976e143df179ec00d1a1ee.jpg: 1024x1024 2 rickshaws, 82.3ms
# image 452/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(260)_jpg.rf.88a6ff8f5fced603679dd4e27e78f9e5.jpg: 1024x1024 1 car, 1 rickshaw, 2 buss, 82.0ms
# image 453/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(261)_jpg.rf.743c1c6a6aa0640ab841c6a29d10b613.jpg: 1024x1024 3 cars, 3 rickshaws, 1 bus, 82.1ms
# image 454/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(262)_jpg.rf.5d3ccab3f3a933c9e7e3e57299234bc6.jpg: 1024x1024 1 car, 2 rickshaws, 1 bus, 82.1ms
# image 455/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(263)_jpg.rf.03d0db5aa784c807bf9533db22290b6d.jpg: 1024x1024 1 rickshaw, 1 bus, 81.9ms
# image 456/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(264)_jpg.rf.10b6523bab965856aed3e6f92dbe52da.jpg: 1024x1024 1 rickshaw, 1 bus, 82.7ms
# image 457/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(265)_jpg.rf.779c5064f24b4016dc45075040e93ee8.jpg: 1024x1024 2 cars, 1 rickshaw, 82.8ms
# image 458/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(266)_jpg.rf.fe35645467b87d79e05b7ac67743a5e8.jpg: 1024x1024 2 cars, 2 rickshaws, 82.3ms
# image 459/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(267)_jpg.rf.8fab973fa509682786b1da707718c910.jpg: 1024x1024 1 rickshaw, 82.4ms
# image 460/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(268)_jpg.rf.c384821ae960f93302304821d3fd9fa5.jpg: 1024x1024 1 car, 1 rickshaw, 82.5ms
# image 461/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(269)_jpg.rf.d6731f50ee76e29ddd737953ee7fc8cc.jpg: 1024x1024 2 cars, 1 rickshaw, 1 bus, 82.8ms
# image 462/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(270)_jpg.rf.afbe1ee8f34834d46cbca0711b33c2f5.jpg: 1024x1024 2 cars, 1 bus, 82.3ms
# image 463/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(271)_jpg.rf.7e229e02ca290a09082e1f3104815064.jpg: 1024x1024 1 bus, 82.3ms
# image 464/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(272)_jpg.rf.84ee4cf90b760d131ac7edbf82c76c8b.jpg: 1024x1024 2 cars, 81.8ms
# image 465/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(273)_jpg.rf.917d0093d1684b05ca7a2db3d47fed3b.jpg: 1024x1024 1 car, 2 rickshaws, 81.9ms
# image 466/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(274)_jpg.rf.8026839d96ed746ba17cb4b4cbd450c2.jpg: 1024x1024 2 rickshaws, 82.2ms
# image 467/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(275)_jpg.rf.ca2094c002d9b6e4bb35213403d0b540.jpg: 1024x1024 1 rickshaw, 83.1ms
# image 468/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(276)_jpg.rf.1d8998e34608964a21eca056262a8495.jpg: 1024x1024 2 rickshaws, 1 bus, 82.5ms
# image 469/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(277)_jpg.rf.cc58f2ca32198d901da4962a9b8e388d.jpg: 1024x1024 1 car, 1 rickshaw, 82.2ms
# image 470/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(278)_jpg.rf.0307226bdf5adcae4c23f3e35ef09430.jpg: 1024x1024 2 rickshaws, 1 bus, 82.1ms
# image 471/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(279)_jpg.rf.1b73844e91805f851f80e116a2cdd436.jpg: 1024x1024 1 rickshaw, 1 bus, 82.2ms
# image 472/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(280)_jpg.rf.a9cc77f7ae5411843f074197e5c8900d.jpg: 1024x1024 1 rickshaw, 1 bus, 82.8ms
# image 473/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(281)_jpg.rf.7c528a33de06a0ee9c86d6b09f5f556e.jpg: 1024x1024 2 rickshaws, 1 bus, 82.8ms
# image 474/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(282)_jpg.rf.841abeed169d40b6ad99fbafb322cd67.jpg: 1024x1024 1 rickshaw, 1 bus, 83.3ms
# image 475/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(283)_jpg.rf.665d72b975d92aed831a2b3d3ba2bd1b.jpg: 1024x1024 2 rickshaws, 1 bus, 82.5ms
# image 476/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(284)_jpg.rf.f0d8a3083e94eb27c678d1ab590db8b4.jpg: 1024x1024 2 rickshaws, 1 bus, 83.1ms
# image 477/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(285)_jpg.rf.f4407d5e4601fe675015f3010c5d3bbb.jpg: 1024x1024 3 rickshaws, 1 bus, 82.4ms
# image 478/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(286)_jpg.rf.457cd435b19e687b14f9e6d08f2100bd.jpg: 1024x1024 3 rickshaws, 1 bus, 82.1ms
# image 479/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(287)_jpg.rf.654a76b46af4f8e693747ff4d1329ccf.jpg: 1024x1024 1 car, 4 rickshaws, 1 bus, 82.4ms
# image 480/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(288)_jpg.rf.4ff913df539f8238963ae6647085a479.jpg: 1024x1024 4 rickshaws, 1 bus, 83.2ms
# image 481/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(289)_jpg.rf.ff59002e097172ae82c9acdd9808f942.jpg: 1024x1024 1 car, 3 rickshaws, 1 bus, 82.4ms
# image 482/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(290)_jpg.rf.610ba4043e25a173509f60d3f89f9a08.jpg: 1024x1024 1 car, 3 rickshaws, 2 buss, 82.5ms
# image 483/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(291)_jpg.rf.e53eb2b14b4829010586b7a1ac0de107.jpg: 1024x1024 2 cars, 4 rickshaws, 2 buss, 82.4ms
# image 484/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(292)_jpg.rf.1918842e4b4e3f3fa3094e3abf5c42a9.jpg: 1024x1024 3 cars, 3 rickshaws, 1 bus, 82.3ms
# image 485/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(293)_jpg.rf.c77bb8cf2a094a91b11f90265cd50ae8.jpg: 1024x1024 2 cars, 2 rickshaws, 1 bus, 82.7ms
# image 486/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(294)_jpg.rf.a893d0d0095536e232867a893a7a7bba.jpg: 1024x1024 3 rickshaws, 1 bus, 82.9ms
# image 487/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(295)_jpg.rf.11ce3b1228e313784ff802dce9fbedc0.jpg: 1024x1024 1 car, 3 rickshaws, 1 bus, 82.1ms
# image 488/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(297)_jpg.rf.3cd624e290aeffc04e9f4e4f7e2cf869.jpg: 1024x1024 1 car, 3 rickshaws, 1 bus, 82.3ms
# image 489/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(298)_jpg.rf.facade9e2a68b70d04ee4c8278efaa83.jpg: 1024x1024 1 car, 1 rickshaw, 1 bus, 82.1ms
# image 490/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(299)_jpg.rf.374710a574064d7a97efe09acacd2275.jpg: 1024x1024 1 car, 2 rickshaws, 1 bus, 82.1ms
# image 491/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(300)_jpg.rf.5c95cec0762afb2c66e8e438911788b4.jpg: 1024x1024 2 cars, 4 rickshaws, 1 bus, 82.8ms
# image 492/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(301)_jpg.rf.1170ed9bae1473adcc41da0a8d92463c.jpg: 1024x1024 3 cars, 2 rickshaws, 1 bus, 82.5ms
# image 493/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(302)_jpg.rf.f3d2d1ed17291539560eede57601ba64.jpg: 1024x1024 3 cars, 2 rickshaws, 1 bus, 82.3ms
# image 494/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(303)_jpg.rf.66506cde12b3e190df17bc28c0fcd878.jpg: 1024x1024 3 cars, 2 rickshaws, 1 bus, 82.5ms
# image 495/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(304)_jpg.rf.43ab27f27507ac52a04623ba76ea08a2.jpg: 1024x1024 1 car, 2 rickshaws, 1 bus, 82.3ms
# image 496/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(305)_jpg.rf.074c9622acab9462d3684ac016a418cc.jpg: 1024x1024 1 car, 3 rickshaws, 1 bus, 82.5ms
# image 497/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(306)_jpg.rf.805d44e365ff6c92ea18f247dabf3406.jpg: 1024x1024 1 car, 5 rickshaws, 1 bus, 82.5ms
# image 498/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(307)_jpg.rf.9254b96641d2c1493221251d6f8dfc17.jpg: 1024x1024 1 car, 4 rickshaws, 3 buss, 82.4ms
# image 499/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(308)_jpg.rf.e32e5aec95792c69753f42b72724057c.jpg: 1024x1024 2 cars, 4 rickshaws, 4 buss, 82.1ms
# image 500/500 /kaggle/input/vehicle-detection-dataset/test1/test/sabiha(309)_jpg.rf.93e77c106e2f415529533bacade2485e.jpg: 1024x1024 2 cars, 1 bus, 82.2ms
# Speed: 5.0ms preprocess, 82.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /kaggle/working/vehdet/preds_test/epoch59_infer
# 440 labels saved to /kaggle/working/vehdet/preds_test/epoch59_infer/labels
# ✅ Predictions saved to: /kaggle/working/vehdet/preds_test/epoch59_infer

# %%
# ==================== 5) BUILD CSV ===================
OUT_DIR_CSV  = "/kaggle/working/vehdet/csv_test"
OUT_DIR_zip  = "/kaggle/working/vehdet/zip_test"
rows = []
for r in results:
    W, H = r.orig_shape[1], r.orig_shape[0]
    img_name = Path(r.path).name
    for b in r.boxes:
        cls_id   = int(b.cls)
        cls_name = model.names.get(cls_id, str(cls_id))
        conf     = float(b.conf)
        # Optional per-class tightening:
        min_need = PER_CLASS_MIN_CONF.get(cls_name, -1.0)
        if min_need > 0 and conf < min_need:
            continue
        x1, y1, x2, y2 = b.xyxy[0].tolist()
        rows.append({
            "image": img_name,
            "class_id": cls_id,
            "class_name": cls_name,
            "conf": round(conf, 6),
            "xmin": round(x1, 1), "ymin": round(y1, 1),
            "xmax": round(x2, 1), "ymax": round(y2, 1),
            "width": W, "height": H,
            "imgsz_used": IMG_USED
        })

df = pd.DataFrame(rows)
csv_path = os.path.join(OUT_DIR_CSV, f"{RUN_NAME}_predictions.csv")
df.to_csv(csv_path, index=False)
print("✅ CSV:", csv_path, f"({len(df)} rows)")

# ==================== 6) ZIP THE RUN =================
shutil.make_archive(os.path.join(OUT_DIR, f"{RUN_NAME}_all"), "zip", pred_dir)
print("📦 Zip created:", os.path.join(OUT_DIR, f"{RUN_NAME}_all.zip"))

print("\nNext: File → Save Version → check 'Save output' so your images/CSV/ZIP persist.")
# Out:
# ✅ CSV: /kaggle/working/vehdet/preds_test/epoch59_infer_predictions.csv (1548 rows)
# 📦 Zip created: /kaggle/working/vehdet/preds_test/epoch59_infer_all.zip
#
# Next: File → Save Version → check 'Save output' so your images/CSV/ZIP persist.

# %%
import os, glob, zipfile

# --- If you used my earlier names, these exist already ---
OUT_DIR  = "/kaggle/working/vehdet/preds_test"
RUN_NAME = "epoch59_infer"   # change if you used a different name

PRED_DIR = os.path.join(OUT_DIR, RUN_NAME)
OUT_DIR_ZIP = "/kaggle/working/vehdet/zip_test"
os.makedirs(OUT_DIR_ZIP, exist_ok=True)

zip_path = os.path.join(OUT_DIR_ZIP, f"{RUN_NAME}_annotated_images.zip")

# Gather ONLY images (skip label txts and any files inside 'labels/')
img_exts = {".jpg", ".jpeg", ".png", ".JPG", ".JPEG", ".PNG"}
files_to_zip = []
for p in glob.glob(os.path.join(PRED_DIR, "**", "*"), recursive=True):
    if os.path.isdir(p): 
        continue
    if "/labels/" in p.replace("\\", "/"):
        continue
    if os.path.splitext(p)[1] in img_exts:
        files_to_zip.append(p)

# Create the ZIP
with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
    for p in files_to_zip:
        zf.write(p, arcname=os.path.relpath(p, PRED_DIR))

print(f"📦 Created: {zip_path}")
print(f"🖼️  Images zipped: {len(files_to_zip)}")

# Tip: File → Save Version → check “Save output” so the zip persists.
# Out:
# 📦 Created: /kaggle/working/vehdet/zip_test/epoch59_infer_annotated_images.zip
# 🖼️  Images zipped: 500

# %%
# ====== CLEAN + REGENERATE LEAN EDA SET ======
import os, glob, xml.etree.ElementTree as ET
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ---- Paths ----
SRC_TRAIN = "/kaggle/input/vehicle-detection-dataset/train/Final Train Dataset"
OUT_DIR   = "/kaggle/working/vehdet/eda"
os.makedirs(OUT_DIR, exist_ok=True)

# ---- Delete any old EDA ZIPs to recover space ----
for z in glob.glob(os.path.join(OUT_DIR, "*.zip")):
    try:
        os.remove(z)
        print("Deleted:", z)
    except Exception as e:
        print("Could not delete", z, "->", e)

# ---- Classes & canonicalization (match training) ----
TARGET_CLASSES = ["car","rickshaw","bus","motorbike"]
CANON_MAP = {
    "minivan": "car",
    "policecar": "car",
    "suv": "car",
    "three wheelers (cng)": "rickshaw",
    "auto rickshaw": "rickshaw",
    "scooter": "motorbike",
}

def clip(v, lo, hi): return max(lo, min(hi, v))

# ---- Parse Pascal-VOC XMLs into a dataframe ----
records = []
xml_files = sorted(glob.glob(os.path.join(SRC_TRAIN, "*.xml")))
print("Found XML files:", len(xml_files))
for xp in xml_files:
    try:
        root = ET.parse(xp).getroot()
    except Exception:
        continue
    fname = (root.findtext("filename") or "").strip()
    img_stem = Path(fname).stem if fname else Path(xp).stem
    try:
        W = int(root.findtext("size/width") or 0)
        H = int(root.findtext("size/height") or 0)
    except:
        continue
    if W <= 0 or H <= 0: 
        continue
    for obj in root.findall("object"):
        cls = (obj.findtext("name") or "").strip().lower()
        cls = CANON_MAP.get(cls, cls)
        if cls not in TARGET_CLASSES:
            continue
        bb = obj.find("bndbox")
        if bb is None: 
            continue
        try:
            xmin = float(bb.findtext("xmin")); ymin = float(bb.findtext("ymin"))
            xmax = float(bb.findtext("xmax")); ymax = float(bb.findtext("ymax"))
        except:
            continue
        xmin = clip(xmin, 0, W-1); xmax = clip(xmax, 0, W-1)
        ymin = clip(ymin, 0, H-1); ymax = clip(ymax, 0, H-1)
        bw = max(1.0, xmax - xmin); bh = max(1.0, ymax - ymin)

        x = (xmin + bw/2) / W
        y = (ymin + bh/2) / H
        w = bw / W
        h = bh / H
        area = w * h
        records.append({"image": img_stem, "class": cls, "x": x, "y": y, "w": w, "h": h, "area": area})

df = pd.DataFrame(records)
print("Parsed objects:", len(df))

# ------- 1) Objects per class -------
fig = plt.figure(figsize=(6,4), dpi=150, constrained_layout=True)
ax = fig.add_subplot(111)
counts = df["class"].value_counts().reindex(TARGET_CLASSES).fillna(0).astype(int)
ax.bar(counts.index, counts.values)
ax.set_title("Objects per Class")
ax.set_ylabel("instances")
for i,v in enumerate(counts.values): ax.text(i, v, str(v), ha="center", va="bottom", fontsize=8)
fig.savefig(os.path.join(OUT_DIR, "01_objects_per_class.png"))
plt.close(fig)

# ------- 2) Width hist -------
fig = plt.figure(figsize=(6,4), dpi=150, constrained_layout=True)
ax = fig.add_subplot(111)
ax.hist(df["w"].clip(0,1), bins=60)
ax.set_xlim(0,1); ax.set_title("BBox Width (normalized)"); ax.set_xlabel("w"); ax.set_ylabel("count")
fig.savefig(os.path.join(OUT_DIR, "02_width_hist.png"))
plt.close(fig)

# ------- 3) Height hist -------
fig = plt.figure(figsize=(6,4), dpi=150, constrained_layout=True)
ax = fig.add_subplot(111)
ax.hist(df["h"].clip(0,1), bins=60)
ax.set_xlim(0,1); ax.set_title("BBox Height (normalized)"); ax.set_xlabel("h"); ax.set_ylabel("count")
fig.savefig(os.path.join(OUT_DIR, "03_height_hist.png"))
plt.close(fig)

# ------- 4) Area hist (log y) -------
fig = plt.figure(figsize=(6,4), dpi=150, constrained_layout=True)
ax = fig.add_subplot(111)
ax.hist(df["area"].clip(0,1), bins=60)
ax.set_yscale("log")
ax.set_xlim(0,1); ax.set_title("BBox Area (normalized)"); ax.set_xlabel("area"); ax.set_ylabel("count (log)")
fig.savefig(os.path.join(OUT_DIR, "04_area_hist_log.png"))
plt.close(fig)

# ------- 5) Center heatmap -------
fig = plt.figure(figsize=(7,5), dpi=150, constrained_layout=True)
ax = fig.add_subplot(111)
h = ax.hist2d(df["x"], df["y"], bins=60, range=[[0,1],[0,1]])
ax.set_title("Object Center Heatmap"); ax.set_xlabel("x"); ax.set_ylabel("y")
cb = fig.colorbar(h[3], ax=ax); cb.set_label("count")
fig.savefig(os.path.join(OUT_DIR, "05_center_heatmap.png"))
plt.close(fig)

# ------- 6) (Optional) Width vs Height hexbin -------
fig = plt.figure(figsize=(6,6), dpi=150, constrained_layout=True)
ax = fig.add_subplot(111)
hb = ax.hexbin(df["w"], df["h"], gridsize=40, extent=(0,1,0,1), mincnt=1, cmap=None)  # default color map
ax.set_title("Width vs Height (hexbin)"); ax.set_xlabel("w"); ax.set_ylabel("h")
cb = fig.colorbar(hb, ax=ax); cb.set_label("count")
fig.savefig(os.path.join(OUT_DIR, "06_width_vs_height_hexbin.png"))
plt.close(fig)

print("✅ Saved minimal EDA plots to:", OUT_DIR)
# Out:
# Deleted: /kaggle/working/vehdet/eda/eda_and_flowchart.zip
# Found XML files: 3003
# Parsed objects: 19853
# ✅ Saved minimal EDA plots to: /kaggle/working/vehdet/eda
